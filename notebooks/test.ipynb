# %%
from python_uv_boilerplate import DEFAULT_TZ, LOG_LEVEL, something

# This is an example Jupyter Notebook showing how to test elements of your application

print(LOG_LEVEL)
print(DEFAULT_TZ)

print(something("Hello World!"))
print(something(23))
